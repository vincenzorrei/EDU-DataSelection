# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from cleaner import clean_dataframe

# %%
# Set the display format for floating point numbers
pd.set_option('display.float_format', lambda x: '%.6f' % x)

# %% [markdown]
# # Data Import
#
# In this section, we import the dataset and perform initial cleaning and exploration. The dataset is loaded into a pandas DataFrame and cleaned using a custom function `clean_dataframe`. We then display the basic information and the first few rows of the dataset to understand its structure and contents.

# %%
# Import the dataset
df = pd.read_csv('https://raw.githubusercontent.com/vincenzorrei/EDU-Datasets/refs/heads/main/Bankrupt.csv')
df = clean_dataframe(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Net Value Per Share (A)              6819 non-null   float64
#  1   Working Capital to Total Assets      6819 non-null   float64
#  2   Current Assets/Total Assets          6819 non-null   float64
#  3   Fixed Assets to Assets               6819 non-null   float64
#  4   Cash/Total Assets                    6819 non-null   float64
#  5   Debt ratio %                         6819 non-null   float64
#  6   Total debt/Total net worth           6819 non-null   float64
#  7   Quick Assets/Current Liability       6819 non-null   float64
#  8   Interest-bearing debt interest rate  6819 non-null   float64
#  9   Equity to Liability                  6819 non-null   float64
#  10  Operating Profit Rate                6819 non-null   float64
#  11  After-tax Net Profit Growth Rate     6819 non-null   float64
#  12  Cash Flow to Total Assets            6819 non-null   float64
#  13  Net Income to Stockholder's Equity   6819 non-null   float64
#  14  Operating Profit Growth Rate         6819 non-null   float64
#  15  Total Asset Turnover                 6819 non-null   float64
#  16  Inventory Turnover Rate (times)      6819 non-null   float64
#  17  Accounts Receivable Turnover         6819 non-null   float64
#  18  Current Ratio                        6819 non-null   float64
#  19  Cash Flow to Sales                   6819 non-null   float64
#  20  Current Asset Turnover Rate          6819 non-null   float64
#  21  Liability-Assets Flag                6819 non-null   int64
#  22  Continuous Net Profit Growth Rate    6819 non-null   float64
#  23  Regular Net Profit Growth Rate       6819 non-null   float64
#  24  Cash Turnover Rate                   6819 non-null   float64
#  25  Bankrupt?                            6819 non-null   int64
# dtypes: float64(24), int64(2)
# memory usage: 1.4 MB

# %%
df.head()
# Out:
#    Net Value Per Share (A)  Working Capital to Total Assets  \
# 0                 0.147950                         0.672775
# 1                 0.182251                         0.751111
# 2                 0.177911                         0.829502
# 3                 0.154187                         0.725754
# 4                 0.167502                         0.751822
#
#    Current Assets/Total Assets  Fixed Assets to Assets  Cash/Total Assets  \
# 0                     0.190643                0.424206           0.004094
# 1                     0.182419                0.468828           0.014948
# 2                     0.602806                0.276179           0.000991
# 3                     0.225815                0.559144           0.018851
# 4                     0.358380                0.309555           0.014161
#
#    Debt ratio %  Total debt/Total net worth  Quick Assets/Current Liability  \
# 0      0.207576                    0.021266                        0.001997
# 1      0.171176                    0.012502                        0.004136
# 2      0.207516                    0.021248                        0.006302
# 3      0.151465                    0.009572                        0.002961
# 4      0.106509                    0.005150                        0.004275
#
#    Interest-bearing debt interest rate  Equity to Liability  ...  \
# 0                             0.000725             0.016469  ...
# 1                             0.000647             0.020794  ...
# 2                             0.000790             0.016474  ...
# 3                             0.000449             0.023982  ...
# 4                             0.000686             0.035490  ...
#
#    Inventory Turnover Rate (times)  Accounts Receivable Turnover  \
# 0                         0.000182                      0.001814
# 1                9360000000.000000                      0.001286
# 2                  65000000.000000                      0.001495
# 3                7130000000.000000                      0.001966
# 4                         0.000163                      0.001449
#
#    Current Ratio  Cash Flow to Sales  Current Asset Turnover Rate  \
# 0       0.002259            0.671568             701000000.000000
# 1       0.006016            0.671570                     0.000107
# 2       0.011543            0.671571                     0.001791
# 3       0.004194            0.671519            8140000000.000000
# 4       0.006022            0.671563            6680000000.000000
#
#    Liability-Assets Flag  Continuous Net Profit Growth Rate  \
# 0                      0                           0.217535
# 1                      0                           0.217620
# 2                      0                           0.217601
# 3                      0                           0.217568
# 4                      0                           0.217626
#
#    Regular Net Profit Growth Rate  Cash Turnover Rate  Bankrupt?
# 0                        0.688979    458000000.000000          1
# 1                        0.689702   2490000000.000000          1
# 2                        0.689470    761000000.000000          1
# 3                        0.689110   2030000000.000000          1
# 4                        0.689697    824000000.000000          1
#
# [5 rows x 26 columns]

# %%
df.describe().T
# Out:
#                                           count              mean  \
# Net Value Per Share (A)             6819.000000          0.190633
# Working Capital to Total Assets     6819.000000          0.814125
# Current Assets/Total Assets         6819.000000          0.522273
# Fixed Assets to Assets              6819.000000    1220120.501590
# Cash/Total Assets                   6819.000000          0.124095
# Debt ratio %                        6819.000000          0.113177
# Total debt/Total net worth          6819.000000    4416336.714259
# Quick Assets/Current Liability      6819.000000    3592902.196830
# Interest-bearing debt interest rate 6819.000000   16448012.905943
# Equity to Liability                 6819.000000          0.047578
# Operating Profit Rate               6819.000000          0.998755
# After-tax Net Profit Growth Rate    6819.000000          0.689146
# Cash Flow to Total Assets           6819.000000          0.649731
# Net Income to Stockholder's Equity  6819.000000          0.840402
# Operating Profit Growth Rate        6819.000000          0.847980
# Total Asset Turnover                6819.000000          0.141606
# Inventory Turnover Rate (times)     6819.000000 2149106056.607619
# Accounts Receivable Turnover        6819.000000   12789705.237554
# Current Ratio                       6819.000000     403284.954245
# Cash Flow to Sales                  6819.000000          0.671531
# Current Asset Turnover Rate         6819.000000 1195855763.308935
# Liability-Assets Flag               6819.000000          0.001173
# Continuous Net Profit Growth Rate   6819.000000          0.217639
# Regular Net Profit Growth Rate      6819.000000          0.689150
# Cash Turnover Rate                  6819.000000 2471976967.444318
# Bankrupt?                           6819.000000          0.032263
#
#                                                   std      min      25%  \
# Net Value Per Share (A)                      0.033474 0.000000 0.173613
# Working Capital to Total Assets              0.059054 0.000000 0.774309
# Current Assets/Total Assets                  0.218112 0.000000 0.352845
# Fixed Assets to Assets               100754158.713168 0.000000 0.085360
# Cash/Total Assets                            0.139251 0.000000 0.033543
# Debt ratio %                                 0.053920 0.000000 0.072891
# Total debt/Total net worth           168406905.281511 0.000000 0.003007
# Quick Assets/Current Liability       171620908.606822 0.000000 0.005240
# Interest-bearing debt interest rate  108275033.532824 0.000000 0.000203
# Equity to Liability                          0.050014 0.000000 0.024477
# Operating Profit Rate                        0.013010 0.000000 0.998969
# After-tax Net Profit Growth Rate             0.013853 0.000000 0.689270
# Cash Flow to Total Assets                    0.047372 0.000000 0.633265
# Net Income to Stockholder's Equity           0.014523 0.000000 0.840115
# Operating Profit Growth Rate                 0.010752 0.000000 0.847984
# Total Asset Turnover                         0.101145 0.000000 0.076462
# Inventory Turnover Rate (times)     3247967014.047812 0.000000 0.000173
# Accounts Receivable Turnover         278259836.984067 0.000000 0.000710
# Current Ratio                         33302155.825480 0.000000 0.007555
# Cash Flow to Sales                           0.009341 0.000000 0.671565
# Current Asset Turnover Rate         2821161238.262308 0.000000 0.000146
# Liability-Assets Flag                        0.034234 0.000000 0.000000
# Continuous Net Profit Growth Rate            0.010063 0.000000 0.217580
# Regular Net Profit Growth Rate               0.013910 0.000000 0.689270
# Cash Turnover Rate                  2938623226.678844 0.000000 0.000274
# Bankrupt?                                    0.176710 0.000000 0.000000
#
#                                                   50%               75%  \
# Net Value Per Share (A)                      0.184400          0.199570
# Working Capital to Total Assets              0.810275          0.850383
# Current Assets/Total Assets                  0.514830          0.689051
# Fixed Assets to Assets                       0.196881          0.372200
# Cash/Total Assets                            0.074887          0.161073
# Debt ratio %                                 0.111407          0.148804
# Total debt/Total net worth                   0.005546          0.009273
# Quick Assets/Current Liability               0.007909          0.012951
# Interest-bearing debt interest rate          0.000321          0.000533
# Equity to Liability                          0.033798          0.052838
# Operating Profit Rate                        0.999022          0.999095
# After-tax Net Profit Growth Rate             0.689439          0.689647
# Cash Flow to Total Assets                    0.645366          0.663062
# Net Income to Stockholder's Equity           0.841179          0.842357
# Operating Profit Growth Rate                 0.848044          0.848123
# Total Asset Turnover                         0.118441          0.176912
# Inventory Turnover Rate (times)              0.000765 4620000000.000000
# Accounts Receivable Turnover                 0.000968          0.001455
# Current Ratio                                0.010587          0.016270
# Cash Flow to Sales                           0.671574          0.671587
# Current Asset Turnover Rate                  0.000199          0.000453
# Liability-Assets Flag                        0.000000          0.000000
# Continuous Net Profit Growth Rate            0.217598          0.217622
# Regular Net Profit Growth Rate               0.689439          0.689647
# Cash Turnover Rate                  1080000000.000000 4510000000.000000
# Bankrupt?                                    0.000000          0.000000
#
#                                                    max
# Net Value Per Share (A)                       1.000000
# Working Capital to Total Assets               1.000000
# Current Assets/Total Assets                   1.000000
# Fixed Assets to Assets               8320000000.000000
# Cash/Total Assets                             1.000000
# Debt ratio %                                  1.000000
# Total debt/Total net worth           9940000000.000000
# Quick Assets/Current Liability       8820000000.000000
# Interest-bearing debt interest rate   990000000.000000
# Equity to Liability                           1.000000
# Operating Profit Rate                         1.000000
# After-tax Net Profit Growth Rate              1.000000
# Cash Flow to Total Assets                     1.000000
# Net Income to Stockholder's Equity            1.000000
# Operating Profit Growth Rate                  1.000000
# Total Asset Turnover                          1.000000
# Inventory Turnover Rate (times)      9990000000.000000
# Accounts Receivable Turnover         9740000000.000000
# Current Ratio                        2750000000.000000
# Cash Flow to Sales                            1.000000
# Current Asset Turnover Rate         10000000000.000000
# Liability-Assets Flag                         1.000000
# Continuous Net Profit Growth Rate             1.000000
# Regular Net Profit Growth Rate                1.000000
# Cash Turnover Rate                  10000000000.000000
# Bankrupt?                                     1.000000

# %%
# Separate the target variable 'Bankrupt?' and the features
y = df['Bankrupt?']
X = df.drop(columns=['Bankrupt?'])

# %%
corr = X.corr()

plt.figure(figsize=(15, 13))
sns.heatmap(corr,
            cmap='coolwarm',
            center=0,
            # annot=True,
            # fmt=".2f",
            linecolor='white',
            linewidths=1
            )
plt.show()

# %%
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten()

for i, col in enumerate(X.columns):
    sns.violinplot(y=X[col], ax=axes[i])
    axes[i].set_title(col)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
col_to_analyze = "Cash Flow to Total Assets"

# %%
color_blue = "#1a559e"
color_black_vivid = "#0070c0"
color_blue_light = "dodgerblue"
color_pink = "#e71d71"
color_black = "black"
color_gold = "#FFD700"
color_orange = "orange"
color_red = "darkred"

# %% [markdown]
# # Outlier Detection

# %%
q1, q2, q3 = np.percentile(X[col_to_analyze], [25, 50, 75])
bins = 80
data = X[col_to_analyze]
q1, q2, q3 = np.percentile(data, [25, 50, 75])

# %%
# Create the histogram with KDE
plt.figure(figsize=(10, 5))
sns.histplot(data, bins=bins, kde=True, color=color_black_vivid, edgecolor="white", alpha=0.7)

# Add lines for the quartiles
plt.axvline(q1, color=color_pink, linestyle="dashed", linewidth=1, label="1° Quartile (Q1)")
plt.axvline(q2, color=color_black, linestyle="dashed", linewidth=1, label="Mediana (Q2)")
plt.axvline(q3, color=color_orange, linestyle="dashed", linewidth=1, label="3° Quartile (Q3)")

# Add labels and title
plt.xlabel(col_to_analyze)
plt.ylabel("Frequency")
plt.title("Histogram with Quartiles")
plt.legend(loc="upper left")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ## 1. Standard Deviation Method

# %% [markdown]
# We **use the Standard Deviation method** on a single column to detect outliers. This method works well when the data are **normally distributed**. The idea is to identify data points that are a certain number of **standard deviations** away from the **mean**. These points are considered **outliers**.

# %%
mean = X[col_to_analyze].mean()
std = X[col_to_analyze].std()
threshold = 2

computed_threshold = threshold * std
computed_threshold_right = mean + computed_threshold 
computed_threshold_left = mean - computed_threshold

standard_deviation_outliers = np.abs(X[col_to_analyze] - mean) > computed_threshold

print(f"Number of outliers: {standard_deviation_outliers.sum()}")
print(f"Percentage of outliers: {standard_deviation_outliers.mean() * 100:.2f}%")
# Out:
# Number of outliers: 399
# Percentage of outliers: 5.85%

# %%
# plot a piechart for percentage exclusion
plt.figure(figsize=(5, 5))
plt.pie([standard_deviation_outliers.mean(), 1 - standard_deviation_outliers.mean()],
        labels=["Outliers", "Non-Outliers"],
        autopct='%1.2f%%',
        colors=[color_red, color_blue_light ])
plt.title(f"Percentage of Outliers: Standard Deviation Method (STD = {threshold})")
plt.show()

# %%
# Create the histogram with KDE
plt.figure(figsize=(10, 5))
sns.histplot(data, bins=bins, kde=True, color=color_black_vivid, edgecolor="white", alpha=0.7)

# Add lines for the quartiles
plt.axvline(q1, color=color_pink, linestyle="dashed", linewidth=1, label="1° Quartile (Q1)")
plt.axvline(q2, color=color_black, linestyle="dashed", linewidth=1, label="Mediana (Q2)")
plt.axvline(q3, color=color_orange, linestyle="dashed", linewidth=1, label="3° Quartile (Q3)")

# Color the area beyond the computed thresholds
outliers_label = f"Outliers ({threshold} STD)"
plt.axvspan(computed_threshold_right, data.max(), color=color_red, alpha=0.3, label=outliers_label)
plt.axvspan(data.min(), computed_threshold_left, color=color_red, alpha=0.3)

# Add labels and title
plt.xlabel(col_to_analyze)
plt.ylabel("Frequency")
plt.title("Histogram with Quartiles: Standard Deviation Method")
plt.legend(loc="upper left")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ## 2. Box Plot Method (IQR)

# %% [markdown]
# The **Box Plot Method** for outlier detection is based on the **Interquartile Range (IQR)**.
# This method identifies outliers by calculating the range within which the central 50% of the data lies. Here's how it works:
#
# 1. **Calculate Quartiles**: Determine the **first quartile (Q1)** and **third quartile (Q3)** of the data.
# 2. **Compute IQR**: Calculate the **IQR** as the difference between Q3 and Q1 (**IQR = Q3 - Q1**).
# 3. **Determine Boundaries**: Define the **lower boundary** as **Q1 - 1.5 * IQR** and the **upper boundary** as **Q3 + 1.5 * IQR**.
# 4. **Identify Outliers**: Data points that fall **below the lower boundary** or **above the upper boundary** are considered **outliers**.
#
# **When It's Convenient**:
# - **Non-Normal Distributions**: Effective for data that is **not normally distributed**.
# - **Skewed Data**: Useful for detecting outliers in **skewed datasets**.
# - **Robustness**: Less affected by **extreme values** compared to methods based on mean and standard deviation.
#
# This method is particularly useful when dealing with **asymmetric data** or when the data contains **extreme values** that could distort the results of other outlier detection methods.

# %%
# Boxplot
plt.figure(figsize=(15, 5))
sns.boxplot(x=data, color=color_blue_light)
plt.title("Boxplot")
plt.xlabel(col_to_analyze)
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %%
IQR = q3 - q1

lower_bound = q1 - 1.5 * IQR
upper_bound = q3 + 1.5 * IQR

box_plot_outliers = (data < lower_bound) | (data > upper_bound)

# Outliers
print(f"Number of outliers: {box_plot_outliers.sum()}")
print(f"Percentage of outliers: {box_plot_outliers.mean() * 100:.2f}%")
# Out:
# Number of outliers: 878
# Percentage of outliers: 12.88%

# %%
# plot a piechart for percentage exclusion
plt.figure(figsize=(5, 5))
plt.pie([box_plot_outliers.mean(), 1 - box_plot_outliers.mean()],
        labels=["Outliers", "Non-Outliers"],
        autopct='%1.2f%%',
        colors=[color_red, color_blue_light ])
plt.title("Percentage of Outliers: Box Plot Method")
plt.show()

# %%
# Create the histogram with KDE
plt.figure(figsize=(10, 5))
sns.histplot(data, bins=bins, kde=True, color=color_black_vivid, edgecolor="white", alpha=0.7)

# Add lines for the quartiles
plt.axvline(q1, color=color_pink, linestyle="dashed", linewidth=1, label="1° Quartile (Q1)")
plt.axvline(q2, color=color_black, linestyle="dashed", linewidth=1, label="Mediana (Q2)")
plt.axvline(q3, color=color_orange, linestyle="dashed", linewidth=1, label="3° Quartile (Q3)")

# Color the area beyond the computed thresholds
plt.axvspan(upper_bound, data.max(), color=color_red, alpha=0.3, label="Outliers")
plt.axvspan(data.min(), lower_bound, color=color_red, alpha=0.3)

# Add labels and title
plt.xlabel(col_to_analyze)
plt.ylabel("Frequency")
plt.title("Histogram with Quartiles: Box Plot Method")
plt.legend(loc="upper left")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %%
# Create the histogram with KDE
plt.figure(figsize=(10, 5))
sns.histplot(data, bins=bins, kde=True, color=color_black_vivid, edgecolor="white", alpha=0.7)

# Add lines for the quartiles
plt.axvline(q1, color=color_pink, linestyle="dashed", linewidth=1, label="1° Quartile (Q1)")
plt.axvline(q2, color=color_black, linestyle="dashed", linewidth=1, label="Mediana (Q2)")
plt.axvline(q3, color=color_orange, linestyle="dashed", linewidth=1, label="3° Quartile (Q3)")

# Color the area beyond the computed by box plot thresholds
plt.axvspan(upper_bound, data.max(), color=color_red, alpha=0.3, label="Outliers Box Plot Method")
plt.axvspan(data.min(), lower_bound, color=color_red, alpha=0.3)

# Color the area beyond the computed by standard deviation thresholds
plt.axvspan(computed_threshold_right, data.max(), color=color_black, alpha=0.3, label=outliers_label)
plt.axvspan(data.min(), computed_threshold_left, color=color_black, alpha=0.3)


# Add labels and title
plt.xlabel(col_to_analyze)
plt.ylabel("Frequency")
plt.title("Histogram with Quartiles: Box Plot Method")
plt.legend(loc="upper left")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()
